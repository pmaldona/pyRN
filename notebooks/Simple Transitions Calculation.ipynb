# %% [markdown]
# # Simple Transitions Calculation
#
# The `RNSRW` module not only enables the calculation of simple random walks, but also allows the estimation of all possible transitions and thus the calculation of global and local resilience by means of a Markovian estimation. This calculation also allows to generate probability weighting on these transitions, as well as on the perturbations, so that favoring one over another can change the resilience. Thus, it is only necessary to calculate the structure of simple transitions, so that by imposing probabilities on it, different resilience frameworks can be obtained.

# %%
# import sys
# !{sys.executable} -m pip install ../. --quiet --user #installation of library in local enviorment
from pyRN import pyRN
import numpy as np

# %% [markdown]
# Once a network has been initialized using the First, it is necessary to create a reaction network, which can be obtained in different ways. One of them corresponds open an existing network text file by use of the function `setFromText`.

# %%
RN=pyRN.setFromText("../networks/rn_test.txt")

# %% [markdown]
# As the function (`setSimpleRw()`). It is necesary to have a list of organizations, this cab ne obteain by calculatinh the synergic structure.

# %%
# Calculation of the generators
RN.setGenerators()
# Calculation of the Closed Reactive Strucutre
RN.setSynStr()
# Out:
# level:  1 from  6 , node:  1  from  2
# level:  1 from  6 , node:  2  from  2
# level:  2 from  6 , node:  1  from  2
# level:  2 from  6 , node:  2  from  2
# level:  3 from  6 , node:  1  from  1
# level:  4 from  6 , node:  1  from  1
# level:  6 from  6 , node:  1  from  1
# 29

# %% [markdown]
# Whit the latter we are in position to calculate the simple transition dictonary. It consists of a dictionary whose keys correspond to a tuple, the starting sets and pertubation set, then each element of this dictionary consists of a list of lists. Each list of this list corresponds as the first component to the perturbed state, and the second to the convergent state (organization). This dictionary can be obtained by means of the function `setSimpleTransDict` that receives as inputs:
#
# - `orglist` : `list` of `bitarrays`.
#     list of organization as species.
# - `pert_type` : `string`.
#     Type of perturbation, can be `"species"` they are considered as species, or `"generators"` if they are considered generators. The default values is `"species"`.
# - `pert_size` : `int`, optional
#     Maximum size of the perturbation (generators). The default is 4.
# - `conn` : `bool`, optional
#     If True only perturbations with connected generators, if False with any. The default is True.
# - `closure` : bool, optional
#     If True closure of the pertrubartion are considered, if False perturbation as any combiantion of generators. The default is True.

# %%
RN.setSimpleTransDict(orglist=RN.SynStrOrgListBtArray,pert_type="generators",pert_size=4,conn=True,closure=True)
RN.setSimpleTransDict(orglist=RN.SynStrOrgListBtArray,pert_type="species",pert_size=4,conn=True,closure=True)

# %% [markdown]
# This function creates a class member dictonary `setSimpleTransGDict` for the generators if the `part_type="generators"` option is used and create the dictonary `setSimpleTransSpDict` the `part_type="species"` is used.

# %%
RN.SimpleTransGDict
# Out:
# {frozenbitarray('111010'): {frozenbitarray('000000'): [[bitarray('111010'),
#     bitarray('111010')]],
#   frozenbitarray('000100'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000001'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000101'): [[bitarray('111111'), bitarray('111111')]]},
#  frozenbitarray('011000'): {frozenbitarray('000000'): [[bitarray('011000'),
#     bitarray('011000')]],
#   frozenbitarray('100000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('000100'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('000001'): [[bitarray('011001'), bitarray('011000')]],
#   frozenbitarray('100100'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('100010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('100001'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000110'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000101'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000011'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('100110'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('100101'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('100011'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('000111'): [[bitarray('111111'), bitarray('111111')]],
#   frozenbitarray('100111'): [[bitarray('111111'), bitarray('111111')]]},
#  frozenbitarray('001000'): {frozenbitarray('000000'): [[bitarray('001000'),
#     bitarray('001000')]],
#   frozenbitarray('100000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010000'): [[bitarray('011000'), bitarray('011000')]],
#   frozenbitarray('000010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('000001'): [[bitarray('001001'), bitarray('001000')]],
#   frozenbitarray('110000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('100010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010001'): [[bitarray('011001'), bitarray('011000')]],
#   frozenbitarray('110010'): [[bitarray('111010'), bitarray('111010')]]},
#  frozenbitarray('111111'): {frozenbitarray('000000'): [[bitarray('111111'),
#     bitarray('111111')]]},
#  frozenbitarray('000010'): {frozenbitarray('000000'): [[bitarray('000010'),
#     bitarray('000010')]],
#   frozenbitarray('100000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('001000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('000001'): [[bitarray('001001'), bitarray('001000')]],
#   frozenbitarray('110000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('101000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('011000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010001'): [[bitarray('011001'), bitarray('011000')]],
#   frozenbitarray('001001'): [[bitarray('001001'), bitarray('001000')]],
#   frozenbitarray('111000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('011001'): [[bitarray('011001'), bitarray('011000')]]},
#  frozenbitarray('000000'): {frozenbitarray('000000'): [[bitarray('000000'),
#     bitarray('000000')]],
#   frozenbitarray('100000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010000'): [[bitarray('011000'), bitarray('011000')]],
#   frozenbitarray('001000'): [[bitarray('001000'), bitarray('001000')]],
#   frozenbitarray('000010'): [[bitarray('000010'), bitarray('000010')]],
#   frozenbitarray('000001'): [[bitarray('001001'), bitarray('001000')]],
#   frozenbitarray('110000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('101000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('100010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('011000'): [[bitarray('011000'), bitarray('011000')]],
#   frozenbitarray('010010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('010001'): [[bitarray('011001'), bitarray('011000')]],
#   frozenbitarray('001010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('001001'): [[bitarray('001001'), bitarray('001000')]],
#   frozenbitarray('111000'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('110010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('101010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('011010'): [[bitarray('111010'), bitarray('111010')]],
#   frozenbitarray('011001'): [[bitarray('011001'), bitarray('011000')]],
#   frozenbitarray('111010'): [[bitarray('111010'), bitarray('111010')]]}}

# %%
RN.SimpleTransSpDict
# Out:
# {frozenbitarray('10011111111'): {frozenbitarray('01100000000'): [[bitarray('01100111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00100000000'): [[bitarray('01100111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('01000000000'): [[bitarray('01000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000000000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]]},
#  frozenbitarray('00000111110'): {frozenbitarray('10000000000'): [[bitarray('10000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000000'): [[bitarray('01000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00100000000'): [[bitarray('00100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000000'): [[bitarray('00010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001000000'): [[bitarray('00001100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000000000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000000001'): [[bitarray('00000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11000000000'): [[bitarray('11000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000000'): [[bitarray('10100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000000001'): [[bitarray('10000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01100000000'): [[bitarray('01100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000000'): [[bitarray('01010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000000'): [[bitarray('01001100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000000'): [[bitarray('00110010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000000'): [[bitarray('00101100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000001'): [[bitarray('00100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010000001'): [[bitarray('00010010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11100000000'): [[bitarray('11100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000001'): [[bitarray('10100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01110000000'): [[bitarray('01110010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000000'): [[bitarray('01101100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000001'): [[bitarray('00110010101'),
#     bitarray('00000000101')]]},
#  frozenbitarray('00000101010'): {frozenbitarray('00000000000'): [[bitarray('00000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('10000000000'): [[bitarray('10000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000000'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00100000000'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00010000000'): [[bitarray('00010100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001000000'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00000010000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000000100'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000000001'): [[bitarray('00000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11000000000'): [[bitarray('11000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000000'): [[bitarray('10100100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000010000'): [[bitarray('10000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000000100'): [[bitarray('10000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000000001'): [[bitarray('10000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01100000000'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01010000000'): [[bitarray('01010100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000000'): [[bitarray('01001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01000010000'): [[bitarray('01000010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000100'): [[bitarray('01000100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000000'): [[bitarray('00110100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000000'): [[bitarray('00101100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010000'): [[bitarray('00100010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000100'): [[bitarray('00100100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000001'): [[bitarray('00100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010010000'): [[bitarray('00010010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000100'): [[bitarray('00010100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000001'): [[bitarray('00010100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00001000100'): [[bitarray('00001100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000010100'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000010001'): [[bitarray('00000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000000101'): [[bitarray('00000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11100000000'): [[bitarray('11100100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000010000'): [[bitarray('11000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000000100'): [[bitarray('11000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100010000'): [[bitarray('10100010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000100'): [[bitarray('10100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000001'): [[bitarray('10100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000010100'): [[bitarray('10000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000010001'): [[bitarray('10000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000000101'): [[bitarray('10000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01110000000'): [[bitarray('01110100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000000'): [[bitarray('01101100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010000'): [[bitarray('01100010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100000100'): [[bitarray('01100100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010000'): [[bitarray('01010010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000100'): [[bitarray('01010100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000100'): [[bitarray('01001100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010100'): [[bitarray('01000010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010000'): [[bitarray('00110010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000100'): [[bitarray('00110100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000001'): [[bitarray('00110100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00101000100'): [[bitarray('00101100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010100'): [[bitarray('00100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010001'): [[bitarray('00100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100000101'): [[bitarray('00100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010010100'): [[bitarray('00010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010010001'): [[bitarray('00010010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010000101'): [[bitarray('00010100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000010101'): [[bitarray('00000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11100010000'): [[bitarray('11100010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11100000100'): [[bitarray('11100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000010100'): [[bitarray('11000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100010100'): [[bitarray('10100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100010001'): [[bitarray('10100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10100000101'): [[bitarray('10100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000010101'): [[bitarray('10000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01110010000'): [[bitarray('01110010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110000100'): [[bitarray('01110000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000100'): [[bitarray('01101000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010100'): [[bitarray('01100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010100'): [[bitarray('01010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010100'): [[bitarray('00110010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010001'): [[bitarray('00110010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00110000101'): [[bitarray('00110100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100010101'): [[bitarray('00100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010010101'): [[bitarray('00010010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11100010100'): [[bitarray('11100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100010101'): [[bitarray('10100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01110010100'): [[bitarray('01110010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010101'): [[bitarray('00110010101'),
#     bitarray('00000000101')]]},
#  frozenbitarray('11111111111'): {frozenbitarray('00000000000'): [[bitarray('10011111111'),
#     bitarray('10011111111')]]},
#  frozenbitarray('00000000101'): {frozenbitarray('00000000000'): [[bitarray('00000000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000000000'): [[bitarray('10000000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01000000000'): [[bitarray('01000000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000000'): [[bitarray('00100000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010000000'): [[bitarray('00010000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00001000000'): [[bitarray('00001000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000100000'): [[bitarray('00000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000010000'): [[bitarray('00000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000001000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000000010'): [[bitarray('00000000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000000000'): [[bitarray('11000000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000000'): [[bitarray('10100000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000100000'): [[bitarray('10000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000010000'): [[bitarray('10000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000001000'): [[bitarray('10000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100000000'): [[bitarray('01100000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000000'): [[bitarray('01010000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000000'): [[bitarray('01001000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000100000'): [[bitarray('01000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010000'): [[bitarray('01000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000001000'): [[bitarray('01000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000010'): [[bitarray('01000000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000000'): [[bitarray('00110000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00101000000'): [[bitarray('00101000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100000'): [[bitarray('00100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100010000'): [[bitarray('00100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100001000'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00100000010'): [[bitarray('00100000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010100000'): [[bitarray('00010100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010010000'): [[bitarray('00010010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010000010'): [[bitarray('00010000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001100000'): [[bitarray('00001100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001001000'): [[bitarray('00001001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001000010'): [[bitarray('00001000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000110000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000101000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000100010'): [[bitarray('00000100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000011000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000010010'): [[bitarray('00000010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000001010'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('11100000000'): [[bitarray('11100000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000100000'): [[bitarray('11000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000010000'): [[bitarray('11000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000001000'): [[bitarray('11000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100100000'): [[bitarray('10100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10100010000'): [[bitarray('10100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000011000'): [[bitarray('10000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110000000'): [[bitarray('01110000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000000'): [[bitarray('01101000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100100000'): [[bitarray('01100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010000'): [[bitarray('01100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100001000'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01100000010'): [[bitarray('01100000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010100000'): [[bitarray('01010100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010000'): [[bitarray('01010010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000010'): [[bitarray('01010000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001100000'): [[bitarray('01001100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001001000'): [[bitarray('01001001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000010'): [[bitarray('01001000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000101000'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01000100010'): [[bitarray('01000100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000011000'): [[bitarray('01000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010010'): [[bitarray('01000010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000001010'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00110100000'): [[bitarray('00110100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00110010000'): [[bitarray('00110010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00110000010'): [[bitarray('00110000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101100000'): [[bitarray('00101100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000010'): [[bitarray('00101000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100101000'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00100100010'): [[bitarray('00100100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010010'): [[bitarray('00100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100001010'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00010100010'): [[bitarray('00010100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010010010'): [[bitarray('00010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001101000'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00001100010'): [[bitarray('00001100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001001010'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00000111000'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000110010'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000101010'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('00000011010'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('11100100000'): [[bitarray('11100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11100010000'): [[bitarray('11100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000011000'): [[bitarray('11000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110100000'): [[bitarray('01110100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110010000'): [[bitarray('01110010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110000010'): [[bitarray('01110000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101100000'): [[bitarray('01101100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000010'): [[bitarray('01101000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100101000'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01100100010'): [[bitarray('01100100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010010'): [[bitarray('01100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100001010'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01010100010'): [[bitarray('01010100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010010'): [[bitarray('01010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001101000'): [[bitarray('01001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01001100010'): [[bitarray('01001100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001001010'): [[bitarray('01001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01000101010'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00110100010'): [[bitarray('00110100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010010'): [[bitarray('00110010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101100010'): [[bitarray('00101100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100101010'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00001101010'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00000111010'): [[bitarray('00000111110'),
#     bitarray('00000111110')]],
#   frozenbitarray('01110100010'): [[bitarray('01110100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110010010'): [[bitarray('01110010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101100010'): [[bitarray('01101100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100101010'): [[bitarray('01100101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01001101010'): [[bitarray('01001101010'),
#     bitarray('00000101010')]]},
#  frozenbitarray('00000000000'): {frozenbitarray('00000000000'): [[bitarray('00000000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000000000'): [[bitarray('10000000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000000'): [[bitarray('01000000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000000'): [[bitarray('00100000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000000'): [[bitarray('00010000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001000000'): [[bitarray('00001000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000100000'): [[bitarray('00000100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000010000'): [[bitarray('00000010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000001000'): [[bitarray('00000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000000100'): [[bitarray('00000000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000000010'): [[bitarray('00000000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000000001'): [[bitarray('00000000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11000000000'): [[bitarray('11000000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000000'): [[bitarray('10100000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000100000'): [[bitarray('10000100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000010000'): [[bitarray('10000010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000001000'): [[bitarray('10000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000000100'): [[bitarray('10000000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000000001'): [[bitarray('10000000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01100000000'): [[bitarray('01100000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000000'): [[bitarray('01010000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000000'): [[bitarray('01001000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000100000'): [[bitarray('01000100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010000'): [[bitarray('01000010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000001000'): [[bitarray('01000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000100'): [[bitarray('01000000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000000010'): [[bitarray('01000000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000000'): [[bitarray('00110000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000000'): [[bitarray('00101000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100000'): [[bitarray('00100100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010000'): [[bitarray('00100010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000100'): [[bitarray('00100000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000010'): [[bitarray('00100000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000001'): [[bitarray('00100000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010100000'): [[bitarray('00010100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010010000'): [[bitarray('00010010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000100'): [[bitarray('00010000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000010'): [[bitarray('00010000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000001'): [[bitarray('00010000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00001100000'): [[bitarray('00001100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001001000'): [[bitarray('00001001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001000100'): [[bitarray('00001000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001000010'): [[bitarray('00001000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000101000'): [[bitarray('00000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00000100100'): [[bitarray('00000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000100010'): [[bitarray('00000100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000100001'): [[bitarray('00000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000011000'): [[bitarray('00000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000010100'): [[bitarray('00000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000010010'): [[bitarray('00000010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000010001'): [[bitarray('00000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000001010'): [[bitarray('00000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00000000110'): [[bitarray('00000000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000000101'): [[bitarray('00000000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11100000000'): [[bitarray('11100000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000100000'): [[bitarray('11000100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000010000'): [[bitarray('11000010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000001000'): [[bitarray('11000001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000000100'): [[bitarray('11000000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100100000'): [[bitarray('10100100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100010000'): [[bitarray('10100010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000100'): [[bitarray('10100000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000001'): [[bitarray('10100000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000100100'): [[bitarray('10000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000100001'): [[bitarray('10000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000011000'): [[bitarray('10000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000010100'): [[bitarray('10000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10000010001'): [[bitarray('10000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000000101'): [[bitarray('10000000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01110000000'): [[bitarray('01110000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000000'): [[bitarray('01101000000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100100000'): [[bitarray('01100100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010000'): [[bitarray('01100010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100000100'): [[bitarray('01100000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100000010'): [[bitarray('01100000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010100000'): [[bitarray('01010100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010000'): [[bitarray('01010010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000100'): [[bitarray('01010000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000010'): [[bitarray('01010000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001100000'): [[bitarray('01001100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001001000'): [[bitarray('01001001000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000100'): [[bitarray('01001000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000010'): [[bitarray('01001000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000101000'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01000100100'): [[bitarray('01000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000100010'): [[bitarray('01000100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000011000'): [[bitarray('01000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010100'): [[bitarray('01000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010010'): [[bitarray('01000010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000001010'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01000000110'): [[bitarray('01000000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110100000'): [[bitarray('00110100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010000'): [[bitarray('00110010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000100'): [[bitarray('00110000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000010'): [[bitarray('00110000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000001'): [[bitarray('00110000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00101100000'): [[bitarray('00101100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000100'): [[bitarray('00101000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000010'): [[bitarray('00101000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100100'): [[bitarray('00100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100010'): [[bitarray('00100100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100001'): [[bitarray('00100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100010100'): [[bitarray('00100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010010'): [[bitarray('00100010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010001'): [[bitarray('00100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100000110'): [[bitarray('00100000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100000101'): [[bitarray('00100000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010100100'): [[bitarray('00010100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010100010'): [[bitarray('00010100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010100001'): [[bitarray('00010100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010010100'): [[bitarray('00010010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010010010'): [[bitarray('00010010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010010001'): [[bitarray('00010010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010000110'): [[bitarray('00010000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010000101'): [[bitarray('00010000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00001101000'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00001100100'): [[bitarray('00001100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001100010'): [[bitarray('00001100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00001001010'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00001000110'): [[bitarray('00001000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000101010'): [[bitarray('00000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00000100110'): [[bitarray('00000100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000100101'): [[bitarray('00000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00000010110'): [[bitarray('00000010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00000010101'): [[bitarray('00000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('11100100000'): [[bitarray('11100100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11100010000'): [[bitarray('11100010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11100000100'): [[bitarray('11100000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000100100'): [[bitarray('11000100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000011000'): [[bitarray('11000011000'),
#     bitarray('00000000000')]],
#   frozenbitarray('11000010100'): [[bitarray('11000010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100100100'): [[bitarray('10100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100010100'): [[bitarray('10100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('10100000101'): [[bitarray('10100000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000100101'): [[bitarray('10000100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('10000010101'): [[bitarray('10000010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('01110100000'): [[bitarray('01110100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110010000'): [[bitarray('01110010000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110000100'): [[bitarray('01110000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01110000010'): [[bitarray('01110000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101100000'): [[bitarray('01101100000'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000100'): [[bitarray('01101000100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01101000010'): [[bitarray('01101000010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100100100'): [[bitarray('01100100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100100010'): [[bitarray('01100100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010100'): [[bitarray('01100010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100010010'): [[bitarray('01100010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01100000110'): [[bitarray('01100000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010100100'): [[bitarray('01010100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010100010'): [[bitarray('01010100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010100'): [[bitarray('01010010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010010010'): [[bitarray('01010010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01010000110'): [[bitarray('01010000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001100100'): [[bitarray('01001100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001100010'): [[bitarray('01001100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('01001000110'): [[bitarray('01001000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000101010'): [[bitarray('01000101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('01000100110'): [[bitarray('01000100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('01000010110'): [[bitarray('01000010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110100100'): [[bitarray('00110100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110100010'): [[bitarray('00110100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010100'): [[bitarray('00110010100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110010010'): [[bitarray('00110010010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000110'): [[bitarray('00110000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00110000101'): [[bitarray('00110000101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00101100100'): [[bitarray('00101100100'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101100010'): [[bitarray('00101100010'),
#     bitarray('00000000000')]],
#   frozenbitarray('00101000110'): [[bitarray('00101000110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100110'): [[bitarray('00100100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100100101'): [[bitarray('00100100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00100010110'): [[bitarray('00100010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00100010101'): [[bitarray('00100010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010100110'): [[bitarray('00010100110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010100101'): [[bitarray('00010100101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00010010110'): [[bitarray('00010010110'),
#     bitarray('00000000000')]],
#   frozenbitarray('00010010101'): [[bitarray('00010010101'),
#     bitarray('00000000101')]],
#   frozenbitarray('00001101010'): [[bitarray('00001101010'),
#     bitarray('00000101010')]],
#   frozenbitarray('00001100110'): [[bitarray('00001100110'),
#     bitarray('00000000000')]]}}

# %% [markdown]
# It is worth mentioning that for a brute force search, i.e. all possible perturbations, the options `pert_size=len(RN.SpidArray)` in case of `part_type="species"` or `pert_size=len(RN.GInBListBt[0])` in case of `part_type="generators"`, with adition `conn=False` option.
