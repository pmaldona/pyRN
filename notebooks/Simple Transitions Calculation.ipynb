# %% [markdown]
# # Simple Transitions Calculation
#
# The `RNSRW` module not only enables the calculation of simple random walks, but also allows the estimation of all possible transitions and thus the calculation of global and local resilience by means of a Markovian estimation. This calculation also allows to generate probability weighting on these transitions, as well as on the perturbations, so that favoring one over another can change the resilience. Thus, it is only necessary to calculate the structure of simple transitions, so that by imposing probabilities on it, different resilience frameworks can be obtained.

# %%
# import sys
# !{sys.executable} -m pip install ../. --quiet --user #installation of library in local enviorment
from pyRN import pyRN
import numpy as np

# %% [markdown]
# Once a network has been initialized using the First, it is necessary to create a reaction network, which can be obtained in different ways. One of them corresponds open an existing network text file by use of the function `setFromText`.

# %%
RN=pyRN.setFromText("../networks/rn_test.txt")

# %% [markdown]
# As the function (`setSimpleRw()`). It is necesary to have a list of organizations, this cab ne obteain by calculatinh the synergic structure.

# %%
# Calculation of the generators
RN.setGenerators()
# Calculation of the Closed Reactive Strucutre
RN.setSynStr()
# Out:
# level:  1 from  6 , node:  1  from  2
# level:  1 from  6 , node:  2  from  2
# level:  2 from  6 , node:  1  from  2
# level:  2 from  6 , node:  2  from  2
# level:  3 from  6 , node:  1  from  1
# level:  4 from  6 , node:  1  from  1
# level:  6 from  6 , node:  1  from  1
# 29

# %% [markdown]
# Whit the latter we are in position to calculate the simple transition dictonary. It consists of a dictionary whose keys correspond to a tuple, the starting sets and pertubation set, then each element of this dictionary consists of a list of lists. Each list of this list corresponds as the first component to the perturbed state, and the second to the convergent state (organization). This dictionary can be obtained by means of the function `setSimpleTransDict` that receives as inputs:
#
# - `orglist` : `list` of `bitarrays`.
#     list of organization as species.
# - `pert_type` : `string`.
#     Type of perturbation, can be `"species"` they are considered as species, or `"generators"` if they are considered generators. The default values is `"species"`.
# - `pert_size` : `int`, optional
#     Maximum size of the perturbation (generators). The default is 4.
# - `conn` : `bool`, optional
#     If True only perturbations with connected generators, if False with any. The default is True.
# - `closure` : bool, optional
#     If True closure of the pertrubartion are considered, if False perturbation as any combiantion of generators. The default is True.

# %%
RN.setSimpleTransDict(orglist=RN.SynStrOrgListBtArray,pert_type="generators",pert_size=4,conn=True,closure=True)
RN.setSimpleTransDict(orglist=RN.SynStrOrgListBtArray,pert_type="species",pert_size=4,conn=True,closure=True)

# %% [markdown]
# This function creates a class member dictonary `setSimpleTransGDict` for the generators if the `part_type="generators"` option is used and create the dictonary `setSimpleTransSpDict` the `part_type="species"` is used.

# %%
RN.SimpleTransGDict
# Out:
# {(frozenbitarray('111010'),
#   frozenbitarray('000000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('111010'),
#   frozenbitarray('000100')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('111010'),
#   frozenbitarray('000001')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('111010'),
#   frozenbitarray('000101')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000000')): [[bitarray('011000'), bitarray('011000')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000100')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000001')): [[bitarray('011001'), bitarray('011000')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100100')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100001')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000110')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000101')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000011')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100110')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100101')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100011')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('000111')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('011000'),
#   frozenbitarray('100111')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('000000')): [[bitarray('001000'), bitarray('001000')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('100000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('010000')): [[bitarray('011000'), bitarray('011000')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('000010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('000001')): [[bitarray('001001'), bitarray('001000')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('110000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('100010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('010010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('010001')): [[bitarray('011001'), bitarray('011000')]],
#  (frozenbitarray('001000'),
#   frozenbitarray('110010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('111111'),
#   frozenbitarray('000000')): [[bitarray('111111'), bitarray('111111')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('000000')): [[bitarray('000010'), bitarray('000010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('100000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('010000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('001000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('000001')): [[bitarray('001001'), bitarray('001000')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('110000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('101000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('011000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('010001')): [[bitarray('011001'), bitarray('011000')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('001001')): [[bitarray('001001'), bitarray('001000')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('111000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000010'),
#   frozenbitarray('011001')): [[bitarray('011001'), bitarray('011000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('000000')): [[bitarray('000000'), bitarray('000000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('100000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('010000')): [[bitarray('011000'), bitarray('011000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('001000')): [[bitarray('001000'), bitarray('001000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('000010')): [[bitarray('000010'), bitarray('000010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('000001')): [[bitarray('001001'), bitarray('001000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('110000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('101000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('100010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('011000')): [[bitarray('011000'), bitarray('011000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('010010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('010001')): [[bitarray('011001'), bitarray('011000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('001010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('001001')): [[bitarray('001001'), bitarray('001000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('111000')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('110010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('101010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('011010')): [[bitarray('111010'), bitarray('111010')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('011001')): [[bitarray('011001'), bitarray('011000')]],
#  (frozenbitarray('000000'),
#   frozenbitarray('111010')): [[bitarray('111010'), bitarray('111010')]]}

# %%
RN.SimpleTransSpDict
# Out:
# {(frozenbitarray('10011111111'),
#   frozenbitarray('01100000000')): [[bitarray('11111111111'),
#    bitarray('11111111111')]],
#  (frozenbitarray('10011111111'),
#   frozenbitarray('01000000000')): [[bitarray('11011111111'),
#    bitarray('10011111111')]],
#  (frozenbitarray('10011111111'),
#   frozenbitarray('00100000000')): [[bitarray('10111111111'),
#    bitarray('10011111111')]],
#  (frozenbitarray('10011111111'),
#   frozenbitarray('00000000000')): [[bitarray('10011111111'),
#    bitarray('10011111111')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10000000000')): [[bitarray('10000111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01000000000')): [[bitarray('01000111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00100000000')): [[bitarray('00100111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00010000000')): [[bitarray('00010111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00001000000')): [[bitarray('00001111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00000000000')): [[bitarray('00000111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00000000001')): [[bitarray('00000111111'),
#    bitarray('00000111110')], [bitarray('00000111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11000000000')): [[bitarray('11000111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10100000000')): [[bitarray('10100111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10010000000')): [[bitarray('10010111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10001000000')): [[bitarray('10001111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10000000001')): [[bitarray('10000111111'),
#    bitarray('00000111110')], [bitarray('10000111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01100000000')): [[bitarray('01100111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01010000000')): [[bitarray('01010111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01001000000')): [[bitarray('01001111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01000000001')): [[bitarray('01000111111'),
#    bitarray('00000111110')], [bitarray('01000111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00110000000')): [[bitarray('00110111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00101000000')): [[bitarray('00101111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00100000001')): [[bitarray('00100111111'),
#    bitarray('00000111110')], [bitarray('00100111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00011000000')): [[bitarray('00011111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00010000001')): [[bitarray('00010111111'),
#    bitarray('00000111110')], [bitarray('00010111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00001000001')): [[bitarray('00001111111'),
#    bitarray('00000111110')], [bitarray('00001111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11100000000')): [[bitarray('11100111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11010000000')): [[bitarray('11010111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11001000000')): [[bitarray('11001111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11000000001')): [[bitarray('11000111111'),
#    bitarray('00000111110')], [bitarray('11000111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10110000000')): [[bitarray('10110111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10101000000')): [[bitarray('10101111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10100000001')): [[bitarray('10100111111'),
#    bitarray('00000111110')], [bitarray('10100111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10011000000')): [[bitarray('10011111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10010000001')): [[bitarray('10010111111'),
#    bitarray('00000111110')], [bitarray('10010111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10001000001')): [[bitarray('10001111111'),
#    bitarray('00000111110')], [bitarray('10001111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01110000000')): [[bitarray('01110111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01101000000')): [[bitarray('01101111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01100000001')): [[bitarray('01100111111'),
#    bitarray('00000111110')], [bitarray('01100111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01011000000')): [[bitarray('01011111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01010000001')): [[bitarray('01010111111'),
#    bitarray('00000111110')], [bitarray('01010111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01001000001')): [[bitarray('01001111111'),
#    bitarray('00000111110')], [bitarray('01001111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00111000000')): [[bitarray('00111111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00110000001')): [[bitarray('00110111111'),
#    bitarray('00000111110')], [bitarray('00110111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00101000001')): [[bitarray('00101111111'),
#    bitarray('00000111110')], [bitarray('00101111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00011000001')): [[bitarray('00011111111'),
#    bitarray('00000111110')], [bitarray('00011111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11110000000')): [[bitarray('11110111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11101000000')): [[bitarray('11101111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11100000001')): [[bitarray('11100111111'),
#    bitarray('00000111110')], [bitarray('11100111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11011000000')): [[bitarray('11011111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11010000001')): [[bitarray('11010111111'),
#    bitarray('00000111110')], [bitarray('11010111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11001000001')): [[bitarray('11001111111'),
#    bitarray('00000111110')], [bitarray('11001111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10111000000')): [[bitarray('10111111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10110000001')): [[bitarray('10110111111'),
#    bitarray('00000111110')], [bitarray('10110111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10101000001')): [[bitarray('10101111111'),
#    bitarray('00000111110')], [bitarray('10101111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10011000001')): [[bitarray('10011111111'),
#    bitarray('10011111111')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01111000000')): [[bitarray('01111111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01110000001')): [[bitarray('01110111111'),
#    bitarray('00000111110')], [bitarray('01110111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01101000001')): [[bitarray('01101111111'),
#    bitarray('00000111110')], [bitarray('01101111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01011000001')): [[bitarray('01011111111'),
#    bitarray('00000111110')], [bitarray('01011111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('00111000001')): [[bitarray('00111111111'),
#    bitarray('00000111110')], [bitarray('00111111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11111000000')): [[bitarray('11111011110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11110000001')): [[bitarray('11110011111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11101000001')): [[bitarray('11101011111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11011000001')): [[bitarray('11011011111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('10111000001')): [[bitarray('10111011111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('01111000001')): [[bitarray('01111011111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000111110'),
#   frozenbitarray('11111000001')): [[bitarray('11111001111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00000000000')): [[bitarray('00000101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10000000000')): [[bitarray('10000101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01000000000')): [[bitarray('01000101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00100000000')): [[bitarray('00100101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00010000000')): [[bitarray('00010101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00001000000')): [[bitarray('00001101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00000010000')): [[bitarray('00000111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00000000100')): [[bitarray('00000101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00000000001')): [[bitarray('00000101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11000000000')): [[bitarray('11000101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10100000000')): [[bitarray('10100101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10010000000')): [[bitarray('10010101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10001000000')): [[bitarray('10001101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10000010000')): [[bitarray('10000111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10000000100')): [[bitarray('10000101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10000000001')): [[bitarray('10000101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01100000000')): [[bitarray('01100101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01010000000')): [[bitarray('01010101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01001000000')): [[bitarray('01001101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01000010000')): [[bitarray('01000111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01000000100')): [[bitarray('01000101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01000000001')): [[bitarray('01000101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00110000000')): [[bitarray('00110101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00101000000')): [[bitarray('00101101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00100010000')): [[bitarray('00100111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00100000100')): [[bitarray('00100101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00100000001')): [[bitarray('00100101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00011000000')): [[bitarray('00011101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00010010000')): [[bitarray('00010111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('
111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10111000000')): [[bitarray('10111101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10110010000')): [[bitarray('10110111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10110000100')): [[bitarray('10110101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10110000001')): [[bitarray('10110101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10101010000')): [[bitarray('10101111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10101000100')): [[bitarray('10101101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10101000001')): [[bitarray('10101101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10100010100')): [[bitarray('10100111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10100010001')): [[bitarray('10100111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10100000101')): [[bitarray('10100101111'),
#    bitarray('00000101010')], [bitarray('10100101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10011010000')): [[bitarray('10011111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10011000100')): [[bitarray('10011101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10011000001')): [[bitarray('10011101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10010010100')): [[bitarray('10010111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10010010001')): [[bitarray('10010111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10010000101')): [[bitarray('10010101111'),
#    bitarray('00000101010')], [bitarray('10010101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10001010100')): [[bitarray('10001111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10001010001')): [[bitarray('10001111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10001000101')): [[bitarray('10001101111'),
#    bitarray('00000101010')], [bitarray('10001101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('10000010101')): [[bitarray('10000111111'),
#    bitarray('00000111110')], [bitarray('10000111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01111000000')): [[bitarray('01111101010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01110010000')): [[bitarray('01110111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01110000100')): [[bitarray('01110101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01110000001')): [[bitarray('01110101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01101010000')): [[bitarray('01101111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01101000100')): [[bitarray('01101101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01101000001')): [[bitarray('01101101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01100010100')): [[bitarray('01100111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01100010001')): [[bitarray('01100111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01100000101')): [[bitarray('01100101111'),
#    bitarray('00000101010')], [bitarray('01100101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01011010000')): [[bitarray('01011111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01011000100')): [[bitarray('01011101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01011000001')): [[bitarray('01011101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01010010100')): [[bitarray('01010111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01010010001')): [[bitarray('01010111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01010000101')): [[bitarray('01010101111'),
#    bitarray('00000101010')], [bitarray('01010101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01001010100')): [[bitarray('01001111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01001010001')): [[bitarray('01001111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01001000101')): [[bitarray('01001101111'),
#    bitarray('00000101010')], [bitarray('01001101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('01000010101')): [[bitarray('01000111111'),
#    bitarray('00000111110')], [bitarray('01000111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00111010000')): [[bitarray('00111111010'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00111000100')): [[bitarray('00111101110'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00111000001')): [[bitarray('00111101011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00110010100')): [[bitarray('00110111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00110010001')): [[bitarray('00110111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00110000101')): [[bitarray('00110101111'),
#    bitarray('00000101010')], [bitarray('00110101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00101010100')): [[bitarray('00101111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00101010001')): [[bitarray('00101111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00101000101')): [[bitarray('00101101111'),
#    bitarray('00000101010')], [bitarray('00101101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00100010101')): [[bitarray('00100111111'),
#    bitarray('00000111110')], [bitarray('00100111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00011010100')): [[bitarray('00011111110'),
#    bitarray('00000111110')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00011010001')): [[bitarray('00011111011'),
#    bitarray('00000101010')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00011000101')): [[bitarray('00011101111'),
#    bitarray('00000101010')], [bitarray('00011101111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00010010101')): [[bitarray('00010111111'),
#    bitarray('00000111110')], [bitarray('00010111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('00001010101')): [[bitarray('00001111111'),
#    bitarray('00000111110')], [bitarray('00001111111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11111000000')): [[bitarray('11111001010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11110010000')): [[bitarray('11110011010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11110000100')): [[bitarray('11110001110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11110000001')): [[bitarray('11110001011'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11101010000')): [[bitarray('11101011010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11101000100')): [[bitarray('11101001110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11101000001')): [[bitarray('11101001011'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11100010100')): [[bitarray('11100011110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11100010001')): [[bitarray('11100011011'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11100000101')): [[bitarray('11100001111'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11011010000')): [[bitarray('11011011010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('11011000100')): [[bitarray('11011001110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000101010'),
#   frozenbitarray('
100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01001000010')): [[bitarray('01001000010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01001000001')): [[bitarray('01001000001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000110000')): [[bitarray('01000110000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000101000')): [[bitarray('01000101000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000100100')): [[bitarray('01000100100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000100010')): [[bitarray('01000100010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000100001')): [[bitarray('01000100001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000011000')): [[bitarray('01000011000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000010100')): [[bitarray('01000010100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000010010')): [[bitarray('01000010010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000010001')): [[bitarray('01000010001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000001100')): [[bitarray('01000001100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000001010')): [[bitarray('01000001010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000001001')): [[bitarray('01000001001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000000110')): [[bitarray('01000000110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000000101')): [[bitarray('01000000101'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('01000000011')): [[bitarray('01000000011'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00111000000')): [[bitarray('00111000000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00110100000')): [[bitarray('00110100000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00110010000')): [[bitarray('00110010000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00110001000')): [[bitarray('00110001000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00110000100')): [[bitarray('00110000100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00110000010')): [[bitarray('00110000010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00110000001')): [[bitarray('00110000001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00101100000')): [[bitarray('00101100000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00101010000')): [[bitarray('00101010000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00101001000')): [[bitarray('00101001000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00101000100')): [[bitarray('00101000100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00101000010')): [[bitarray('00101000010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00101000001')): [[bitarray('00101000001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100110000')): [[bitarray('00100110000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100101000')): [[bitarray('00100101000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100100100')): [[bitarray('00100100100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100100010')): [[bitarray('00100100010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100100001')): [[bitarray('00100100001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100011000')): [[bitarray('00100011000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100010100')): [[bitarray('00100010100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100010010')): [[bitarray('00100010010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100010001')): [[bitarray('00100010001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100001100')): [[bitarray('00100001100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100001010')): [[bitarray('00100001010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100001001')): [[bitarray('00100001001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100000110')): [[bitarray('00100000110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100000101')): [[bitarray('00100000101'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00100000011')): [[bitarray('00100000011'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00011100000')): [[bitarray('00011100000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00011010000')): [[bitarray('00011010000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00011001000')): [[bitarray('00011001000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00011000100')): [[bitarray('00011000100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00011000010')): [[bitarray('00011000010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00011000001')): [[bitarray('00011000001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010110000')): [[bitarray('00010110000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010101000')): [[bitarray('00010101000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010100100')): [[bitarray('00010100100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010100010')): [[bitarray('00010100010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010100001')): [[bitarray('00010100001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010011000')): [[bitarray('00010011000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010010100')): [[bitarray('00010010100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010010010')): [[bitarray('00010010010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010010001')): [[bitarray('00010010001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010001100')): [[bitarray('00010001100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010001010')): [[bitarray('00010001010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010001001')): [[bitarray('00010001001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010000110')): [[bitarray('00010000110'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010000101')): [[bitarray('00010000101'),
#    bitarray('00000000101')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00010000011')): [[bitarray('00010000011'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001110000')): [[bitarray('00001110000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001101000')): [[bitarray('00001101000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001100100')): [[bitarray('00001100100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001100010')): [[bitarray('00001100010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001100001')): [[bitarray('00001100001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001011000')): [[bitarray('00001011000'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001010100')): [[bitarray('00001010100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001010010')): [[bitarray('00001010010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001010001')): [[bitarray('00001010001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001001100')): [[bitarray('00001001100'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001001010')): [[bitarray('00001001010'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001001001')): [[bitarray('00001001001'),
#    bitarray('00000000000')]],
#  (frozenbitarray('00000000000'),
#   frozenbitarray('00001000110')): [[bitarray('00001000110'),
#    bitarray('00000000000')]],
#  ...}

# %% [markdown]
# It is worth mentioning that for a brute force search, i.e. all possible perturbations, the options `pert_size=len(RN.SpidArray)` in case of `part_type="species"` or `pert_size=len(RN.GInBListBt[0])` in case of `part_type="generators"`, with adition `conn=False` option.
